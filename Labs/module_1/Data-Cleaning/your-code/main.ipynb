# %% [markdown]
# # Data Cleaning
#
# #### 1. Import pandas library.

# %%
import pandas as pd

# %% [markdown]
# #### 2. Import pymysql and sqlalchemy as you have learnt in the lesson of importing/exporting data.

# %%
import pymysql
from sqlalchemy import create_engine
from getpass import getpass

# %% [markdown]
# #### 3. Create a mysql engine to set the connection to the server. Check the connection details in [this link](https://relational.fit.cvut.cz/dataset/Stats).

# %%
username='guest'
password=getpass()
engine=create_engine(f'mysql+pymysql://{username}:{password}@relational.fit.cvut.cz/stats')
# Out:
# ········

# %% [markdown]
# #### 4. Import the users table.

# %%
dfu=pd.read_sql_query('SELECT * FROM users', engine)

# %% [markdown]
# #### 5. Rename Id column to userId.

# %%
dfu=dfu.rename(columns={'Id':'userId'})
# Out:
#     userId  Reputation        CreationDate         DisplayName  \
# 0       -1           1 2010-07-19 06:55:26           Community
# 1        2         101 2010-07-19 14:01:36        Geoff Dalgas
# 2        3         101 2010-07-19 15:34:50        Jarrod Dixon
# 3        4         101 2010-07-19 19:03:27              Emmett
# 4        5        6792 2010-07-19 19:03:57               Shane
# 5        6         457 2010-07-19 19:04:07              Harlan
# 6        7         429 2010-07-19 19:04:37               Vince
# 7        8        6764 2010-07-19 19:04:52         csgillespie
# 8       10         121 2010-07-19 19:05:40              Pierre
# 9       11         136 2010-07-19 19:06:02            wahalulu
# 10      12         101 2010-07-19 19:06:34                 Jin
# 11      13         817 2010-07-19 19:06:49             Sharpie
# 12      15          11 2010-07-19 19:07:32       hannes.koller
# 13      16         101 2010-07-19 19:08:13           slashnick
# ...

# %% [markdown]
# #### 6. Import the posts table.

# %%
dfp=pd.read_sql_query('SELECT * FROM posts', engine)

# %% [markdown]
# #### 7. Rename Id column to postId and OwnerUserId to userId.

# %%
dfp=dfp.rename(columns={'Id':'postId','OwnerUserId':'userId'})

# %% [markdown]
# #### 8. Define new dataframes for users and posts with the following selected columns:
# **users columns**: userId, Reputation, Views, UpVotes, DownVotes
# **posts columns**: postId, Score, userID, ViewCount, CommentCount

# %%
dfu2 = dfu[['userId', 'Reputation', 'Views', 'UpVotes', 'DownVotes']]
dfp2 = dfp[['postId', 'Score', 'userId', 'ViewCount', 'CommentCount']]

# %% [markdown]
# #### 9. Merge the new dataframes you have created, of users and posts.
# You will need to make an inner [merge](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.merge.html) of posts and users dataframes.

# %%
newm=dfu2.merge(dfp2, left_on='userId', right_on='userId')
newm
# Out:
#        userId  Reputation  Views  UpVotes  DownVotes  postId  Score  \
# 0          -1           1      0     5007       1920    2175      0
# 1          -1           1      0     5007       1920    8576      0
# 2          -1           1      0     5007       1920    8578      0
# 3          -1           1      0     5007       1920    8981      0
# 4          -1           1      0     5007       1920    8982      0
# ...       ...         ...    ...      ...        ...     ...    ...
# 90579   55734           1      0        0          0  115352      0
# 90580   55738          11      0        0          0  115360      2
# 90581   55742           6      0        0          0  115366      1
# 90582   55744           6      1        0          0  115370      1
# 90583   55746         106      1        0          0  115376      1
#
#        ViewCount  CommentCount
# 0            NaN             0
# 1            NaN             0
# 2            NaN             0
# ...

# %% [markdown]
# #### 10. How many missing values do you have in your merged dataframe? On which columns?

# %%
newm.isna().sum()
newm.describe()
#There are 48 396 missing values, all in ViewCount
# Out:
#              userId    Reputation         Views       UpVotes     DownVotes  \
# count  90584.000000  90584.000000  90584.000000  90584.000000  90584.000000
# mean   16546.764727   6282.395412   1034.245176    734.315718     33.273249
# std    15273.367108  15102.268670   2880.074012   2050.869327    134.936435
# min       -1.000000      1.000000      0.000000      0.000000      0.000000
# 25%     3437.000000     60.000000      5.000000      1.000000      0.000000
# 50%    11032.000000    396.000000     45.000000     22.000000      0.000000
# 75%    27700.000000   4460.000000    514.250000    283.000000      8.000000
# max    55746.000000  87393.000000  20932.000000  11442.000000   1920.000000
#
#               postId         Score      ViewCount  CommentCount
# count   90584.000000  90584.000000   42188.000000  90584.000000
# mean    56539.080522      2.780767     556.656158      1.894650
# std     33840.307529      4.948922    2356.930779      2.638704
# ...

# %% [markdown]
# #### 11. You will need to make something with missing values.  Will you clean or filling them? Explain.
# **Remember** to check the results of your code before going to the next step.

# %%
#There are more than 50% of missing values in this column so it could have a great impact on any calculations. I that case I would fill it with "0"
newm[['ViewCount']]=newm[['ViewCount']].fillna(0)
newm
# Out:
#        userId  Reputation  Views  UpVotes  DownVotes  postId  Score  \
# 0          -1           1      0     5007       1920    2175      0
# 1          -1           1      0     5007       1920    8576      0
# 2          -1           1      0     5007       1920    8578      0
# 3          -1           1      0     5007       1920    8981      0
# 4          -1           1      0     5007       1920    8982      0
# ...       ...         ...    ...      ...        ...     ...    ...
# 90579   55734           1      0        0          0  115352      0
# 90580   55738          11      0        0          0  115360      2
# 90581   55742           6      0        0          0  115366      1
# 90582   55744           6      1        0          0  115370      1
# 90583   55746         106      1        0          0  115376      1
#
#        ViewCount  CommentCount
# 0            0.0             0
# 1            0.0             0
# 2            0.0             0
# ...

# %% [markdown]
# #### 12. Adjust the data types in order to avoid future issues. Which ones should be changed?

# %%
newm['ViewCount']=[int(i) for i in newm['ViewCount']]

# %%
newm.dtypes
# Out:
# userId          int64
# Reputation      int64
# Views           int64
# UpVotes         int64
# DownVotes       int64
# postId          int64
# Score           int64
# ViewCount       int64
# CommentCount    int64
# dtype: object
