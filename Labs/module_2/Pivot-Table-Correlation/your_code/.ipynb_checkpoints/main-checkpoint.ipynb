# %% [markdown]
# # Before you start :
#    - These exercises are related to the Pivot table and correlation lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import pandas as pd
import numpy as np

# %% [markdown]
# # Challenge 1
#
# #### Read the `employees` dataset from Ironhack's database:
# * db: `employees`
# * table: `employees`
#
# Save your data in a variable called `employees`.

# %%
# your code here
employees=pd.read_csv('employees.csv')
employees
# Out:
#     Department Education      Title      Name  Years  Salary
# 0        Admin    Master  associate     David      4      58
# 1           IT    Master  associate    Thomas      7      45
# 2        Admin    Master  associate     Diana     10      52
# 3        Admin    Master         VP  Manuella     15      33
# 4        Sales    Master    Analyst     Carla      6      38
# ..         ...       ...        ...       ...    ...     ...
# 495      Sales       PhD         VP    Calvin      2     119
# 496         HR    Master    Analyst    Dustin      6      67
# 497      Sales       PhD         VP   Winston     13      93
# 498         IT       PhD    Analyst      Earl     12     108
# 499      Sales    Master    Analyst     Alvin     13      48
#
# [500 rows x 6 columns]

# %% [markdown]
# #### What's the mean `Salary` by `Department`?
# **Tip**: There are 2 ways to do it: with or without pivot tables. Do it both ways.

# %%
# Method 1
# your code here
employees.groupby('Department')['Salary'].mean()
# Out:
# Department
# Admin    76.325203
# HR       74.237705
# IT       70.671642
# Sales    73.132231
# Name: Salary, dtype: float64

# %%
# Method 2
# your code here
employees.pivot_table(index='Department',values='Salary',aggfunc='mean')
# Out:
#                Salary
# Department
# Admin       76.325203
# HR          74.237705
# IT          70.671642
# Sales       73.132231

# %% [markdown]
# #### Now, group the data by more than one column. Use Pandas pivot table function to select the mean `Salary` by `Department` and `Title`.

# %%
# your code here
employees.pivot_table(index=['Department','Title'],values='Salary',aggfunc='mean')
# Out:
#                          Salary
# Department Title
# Admin      Analyst    77.736842
#            VP         75.571429
#            associate  75.813953
# HR         Analyst    71.404762
#            VP         75.441176
#            associate  75.934783
# IT         Analyst    69.600000
#            VP         74.000000
#            associate  68.095238
# Sales      Analyst    76.074074
#            VP         66.675000
#            associate  76.814815

# %% [markdown]
# #### Display the number of `Years` of work experience and the `Salary` for each `Title`. Add `Years` as a column in your pivot table.
# **Hint**: Use Pandas documentation to explore the [pivot table](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.pivot_table.html) function.

# %%
# your code here
employees.pivot_table(index='Title',values=['Salary'],columns='Years')
# Out:
#               Salary                                                         \
# Years             1          2          3          4          5          6
# Title
# Analyst    75.000000  63.384615  73.388889  77.600000  77.615385  87.444444
# VP         74.714286  83.200000  69.000000  82.333333  80.000000  61.071429
# associate  77.333333  83.250000  83.562500  73.300000  64.333333  74.454545
#
#                                                                              \
# Years             7          8          9          10         11         12
# Title
# Analyst    67.000000  78.000000  86.454545  73.666667  71.181818  68.642857
# VP         78.692308  54.181818  65.666667  70.400000  79.363636  76.222222
# associate  70.166667  69.500000  76.090909  73.941176  73.750000  77.700000
#
#
# Years             13         14         15
# Title
# Analyst    69.571429  70.000000  71.200000
# VP         87.000000  74.785714  72.272727
# associate  62.222222  62.800000  64.500000

# %% [markdown]
# #### Find the mean `Salary` and number of employees in each `Department` and for each job `Title`.

# %%
# your code here
employees.pivot_table(index=['Department','Title'],values=['Salary'], aggfunc=['mean','count'])
# Out:
#                            mean  count
#                          Salary Salary
# Department Title
# Admin      Analyst    77.736842     38
#            VP         75.571429     42
#            associate  75.813953     43
# HR         Analyst    71.404762     42
#            VP         75.441176     34
#            associate  75.934783     46
# IT         Analyst    69.600000     45
#            VP         74.000000     47
#            associate  68.095238     42
# Sales      Analyst    76.074074     54
#            VP         66.675000     40
#            associate  76.814815     27

# %% [markdown]
# #### For each `Department` and each job `Title`, find the `Salary` median, minimum, maximum and standard deviation. Comment your results.

# %%
# your code here
employees.pivot_table(index=['Department','Title'],values=['Salary'], aggfunc=['median','min','max','std'])
# Out:
#                      median    min    max        std
#                      Salary Salary Salary     Salary
# Department Title
# Admin      Analyst     80.5     33    120  26.335347
#            VP          75.5     31    120  24.927351
#            associate   79.0     30    119  26.524253
# HR         Analyst     72.5     31    119  25.093056
#            VP          76.5     32    119  26.594817
#            associate   76.0     30    119  28.063739
# IT         Analyst     69.0     30    119  28.418464
#            VP          71.0     31    120  25.568323
#            associate   59.5     33    117  28.557866
# Sales      Analyst     72.0     30    120  27.855999
#            VP          60.0     30    119  27.017931
#            associate   79.0     31    120  28.266638

# %%
"""
your commments here
I notice that the median and standard deviation are pretty far from each other
"""

# %% [markdown]
# #### Based on your comments, fill the missing values with an appropriate value.

# %%
# your code here
employees.isna().sum()
#There are no missing values
# Out:
# Department    0
# Education     0
# Title         0
# Name          0
# Years         0
# Salary        0
# dtype: int64

# %% [markdown]
# #### The stake holders want to know, for each `Department`, the number of employees and how much money is spent on salaries. Could you provide that information?

# %%
# your code here
employees.pivot_table(index='Department',values=['Name','Salary'], aggfunc=['count','sum'])
# Out:
#            count           sum
#             Name Salary Salary
# Department
# Admin        123    123   9388
# HR           122    122   9057
# IT           134    134   9470
# Sales        121    121   8849

# %% [markdown]
# #### For each `Department` and `Title`, find the the total years of work experience and the mean `Salary`.

# %%
# your code here
employees.pivot_table(index=['Department','Title'],values=['Years','Salary'], aggfunc=['sum','mean'])
# Out:
#                         sum             mean
#                      Salary Years     Salary     Years
# Department Title
# Admin      Analyst     2954   292  77.736842  7.684211
#            VP          3174   342  75.571429  8.142857
#            associate   3260   306  75.813953  7.116279
# HR         Analyst     2999   326  71.404762  7.761905
#            VP          2565   198  75.441176  5.823529
#            associate   3493   351  75.934783  7.630435
# IT         Analyst     3132   346  69.600000  7.688889
#            VP          3478   409  74.000000  8.702128
#            associate   2860   336  68.095238  8.000000
# Sales      Analyst     4108   441  76.074074  8.166667
#            VP          2667   293  66.675000  7.325000
#            associate   2074   138  76.814815  5.111111

# %% [markdown]
# ## Bonus Challenge 1
#
# #### Compute the mean `Salary` after removing the maximum `Salary` for each `Department`. Create the appropriate pivot table.
# **Hint**: Write a custom function.

# %%
# your code here
A FAIRE

a=employees.loc[(employees['Department']=='Admin') & (employees['Salary']==employees['Salary'].max())]
b=employees[(employees['Department']=='IT') & (employees['Salary']==employees['Salary'].max())]
c=employees[(employees['Department']=='Sales') & (employees['Salary']==employees['Salary'].max())]
d=employees[(employees['Department']=='HR') & (employees['Salary']==119)]

# %%
employees.drop(employees.loc[(employees['Department']=='Admin') & (employees['Salary']==employees['Salary'].max())])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-73-bf563d46e821> in <module>
# ----> 1 employees.drop(employees.loc[(employees['Department']=='Admin') & (employees['Salary']==employees['Salary'].max())])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %% [markdown]
# # Challenge 2
#
# #### Read the `fitbit` dataset from Ironhack's database:
# * db: `fitbit`
# * table: `fitbit`
#
# Save your data in a variable called `fitbit`.

# %%
# your code here
fitbit=pd.read_csv('fitbit.csv')
fitbit
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    08-05-2015            1934    905      0.65       0              1.355
# 1    09-05-2015            3631  18925     14.11       4            611.000
# 2    10-05-2015            3204  14228     10.57       1            602.000
# 3    11-05-2015            2673   6756      5.02       8            749.000
# 4    12-05-2015            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  03-05-2016            3796  18588     14.13      16            599.000
# 363  04-05-2016            3525  16382     12.39      16            684.000
# 364  05-05-2016            3649  21913     16.40      19            701.000
# 365  06-05-2016            3539  19023     14.79      15            575.000
# 366  07-05-2016             304   9526      7.08       2            564.000
#
# ...

# %% [markdown]
# #### Explore you dataset in terms of data types and descriptive statistics.
# **Hint**: Use Pandas functions from previous lectures.

# %%
# your code here
fitbit.dtypes
# Out:
# Date                       object
# Calorie burned              int64
# Steps                       int64
# Distance                  float64
# Floors                      int64
# Minutes Sedentary         float64
# Minutes Lightly Active      int64
# Minutes Fairly Active       int64
# Minutes Very Active         int64
# Activity Calories           int64
# MinutesOfSleep              int64
# MinutesOfBeingAwake         int64
# NumberOfAwakings            int64
# LengthOfRestInMinutes       int64
# dtype: object

# %%
fitbit.describe()
# Out:
#        Calorie burned         Steps    Distance      Floors  \
# count      367.000000    367.000000  367.000000  367.000000
# mean      2741.501362  10121.588556    8.549128   11.724796
# std        916.307036   5594.836225    3.409881   10.337370
# min        179.000000      0.000000    0.000000    0.000000
# 25%       2698.000000   6730.500000    6.155000    5.000000
# 50%       2974.000000  10413.000000    8.290000   11.000000
# 75%       3233.000000  13916.500000   10.560000   16.000000
# max       4351.000000  26444.000000   20.450000  101.000000
#
#        Minutes Sedentary  Minutes Lightly Active  Minutes Fairly Active  \
# count         367.000000              367.000000             367.000000
# mean          563.934482              236.405995              26.163488
# std           294.793145               86.531376              20.319456
# min             1.002000                0.000000               0.000000
# ...

# %% [markdown]
# #### You suspect that there must be a linear relationship between the `Minutes Very Active` and the `Steps`. Compute the correlation between these variables.

# %%
# your code here
np.corrcoef(fitbit['Minutes Very Active'],fitbit.Steps)
# Out:
# array([[1.        , 0.57145185],
#        [0.57145185, 1.        ]])

# %% [markdown]
# #### Use matplotlib to visually plot `Minutes Very active` vs `Steps`. We'll work with matplotlib next week. As a first introduction, uncomment and complete the following code. You need to replace the # symbol for the correct function arguments.

# %%
import matplotlib.pyplot as plt;

# %%
"""
plt.scatter(#, #)
plt.title(#)
plt.xlabel(#)
plt.ylabel(#)
plt.show()
"""
x=fitbit['Minutes Very Active']
y=fitbit['Steps']
plt.scatter(x,y)
plt.title('Correlation between Minutes Very Active and number of steps')
plt.xlabel('Minutes Very Active')
plt.ylabel('Steps')
plt.show()

# %% [markdown]
# #### What can you say about `Minutes Very Active` and `Steps`? Write a comment below.

# %%
"""
It seems like there is indeed a correlation : the less minutes someone is active, the less steps they take on average
"""

# %% [markdown]
# #### We also suspect that there must be a linear relationship between the `Minutes Sedentary` and the `Steps`. Compute the correlation between these variables.

# %%
# your code here
np.corrcoef(fitbit['Minutes Sedentary'],fitbit.Steps)
# Out:
# array([[1.        , 0.07690608],
#        [0.07690608, 1.        ]])

# %% [markdown]
# #### Use matplotlib to visually plot `Minutes Sedentary` vs `Steps`. Based on the results of the computed correlation and the plot, what can you say about these 2 variables?

# %%
# your code here
x=fitbit['Minutes Sedentary']
y=fitbit['Steps']
plt.scatter(x,y)
plt.title('Correlation between Minutes Sedentary and number of steps')
plt.xlabel('Minutes Sedentary')
plt.ylabel('Steps')
plt.show()

# %%
"""
The correlation is less obvious here but on the left side, it looks like the more sedenary someone is, the less steps they take

"""

# %% [markdown]
# #### We also suspect that there must be a linear relationship between the `MinutesOfSleep` and the `Steps`. Compute the correlation between these variables.

# %%
# your code here
np.corrcoef(fitbit['MinutesOfSleep'],fitbit.Steps)
# Out:
# array([[1.        , 0.13098566],
#        [0.13098566, 1.        ]])

# %% [markdown]
# #### Use matplotlib to visually plot `MinutesOfSleep` vs `Steps`. Based on the results of the computed correlation and the plot, what can you say about these 2 variables?

# %%
# your code here
x=fitbit['MinutesOfSleep']
y=fitbit['Steps']
plt.scatter(x,y)
plt.title('Correlation between Minutes of sleep and number of steps')
plt.xlabel('Minutes of sleep')
plt.ylabel('Steps')
plt.show()

# %%
"""
Here there is no correlation at all, be it based on the mathematical form or the graph
"""

# %% [markdown]
# #### Select a subset of your dataset with the columns below and compute the correlation matrix. Save the results in the variable `cor_fit`.

# %%
columns = ['Calorie burned', 'Steps', 'Floors', 'Minutes Sedentary', 'Minutes Very Active', 'MinutesOfSleep']
#fitbit[fitbit['Steps']].corr()[columns]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-114-4ef67faf4bdd> in <module>
#       1 columns = ['Calorie burned', 'Steps', 'Floors', 'Minutes Sedentary', 'Minutes Very Active', 'MinutesOfSleep']
# ----> 2 fitbit[fitbit['Steps']].corr()[columns]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1551
# -> 1552         self._validate_read_indexer(
# ...

# %%
# your code here
fitbit['Activity Calories'].corr(columns)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-108-26f8fecea119> in <module>
#       1 # your code here
# ----> 2 fitbit['Activity Calories'].corr(columns)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in corr(self, other, method, min_periods)
#    2246         0.3
#    2247         """
# -> 2248         this, other = self.align(other, join="inner", copy=False)
#    2249         if len(this) == 0:
#    2250             return np.nan
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in align(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis, broadcast_axis)
#    3936         broadcast_axis=None,
#    3937     ):
# -> 3938         return super().align(
#    3939             other,
#    3940             join=join,
#
# ...

# %% [markdown]
# #### Based on the result of the correlation matrix, which of the features are highly correlated with variable `Steps`?
# **Hint**: sort the correlations of `Steps` vs the rest of the features in descending order. You can use Pandas `sort_values`.

# %%
# your code here
#A FAIRE

# %% [markdown]
# # Challenge 3
#
# #### Read the `time_grades` dataset from Ironhack's database:
# * db: `time_grades`
# * table: `time_grades`
#
# Save your data in a variable called `time_grades`.

# %%
# your code here
time_grades=pd.read_csv('time_grades.csv')
time_grades
# Out:
#         Name  Study time  Grade
# 0       Jose           4      4
# 1      Maria           9      7
# 2      David           8      9
# 3      Sonia          10      7
# 4     Samuel          20      9
# 5        Eva           5      3
# 6     Carlos          12      7
# 7      Pedro           6      5
# 8        Ana          18      9
# 9   Gervasio           7      3
# 10     Gemma           7      8
# 11    Alicia          11      7
# 12  Jonathan           2      1
# 13  Cristina          13      8
# 14     Pilar           3      2

# %% [markdown]
# #### Show visually the frequency distribution of the `time_grades` dataset.

# %%
# your code here
time_grades.plot.hist()

# %% [markdown]
# #### Is there a correlation between `Study time` and `Grade`? Use both Pearson and Spearman correlations and comment your results.

# %%
# your code here
time_grades.corr()
# Out:
#             Study time     Grade
# Study time    1.000000  0.798046
# Grade         0.798046  1.000000

# %%
time_grades.corr(method="spearman")
# Out:
#             Study time     Grade
# Study time    1.000000  0.819659
# Grade         0.819659  1.000000

# %%
"""
In both cases, there is a high correlation between the study time and grade. The higher is the study time, the higher the grade
"""

# %% [markdown]
# #### Use matplotlib to visually plot `Study time` vs `Grade`. Based on the results of the computed correlation and the plot, what can you say about these 2 variables?

# %%
# your code here
x=time_grades['Study time']
y=time_grades['Grade']
plt.bar(x,y)
plt.title('Correlation between Study Time and Grade')
plt.xlabel('Study Time')
plt.ylabel('Grade')
plt.show()

# %%
"""
There is defiitely a high correlation between these 2 variables
"""

# %% [markdown]
# #### Could you explain the difference between Pearson and Spearman correlations?

# %%
"""
The Spearman correlation only works for unique values and is based on rankings
"""
